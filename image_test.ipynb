# %%
import PIL
import numpy as np
import pickle
from PIL import Image
import matplotlib.pyplot as plt

# %%
#/home/jim/projects/contra/test_inputs_dump_1542560562.p
obs = pickle.load(open("test_inputs_dump_1542560562.p","rb"))
np.shape(obs)
# Out:
# (1024, 128, 112, 4)

# %%
obs_index = 0

# %%
Image.fromarray(np.array(obs[obs_index][:,:,0]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34F7E588>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,1]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34F0AC88>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,2]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34F0AEB8>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,3]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34F0AF98>

# %%
obs_index = 1023

# %%
Image.fromarray(np.array(obs[obs_index][:,:,0]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34E990B8>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,1]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34E99160>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,2]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34E991D0>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,3]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7FEC34E992E8>

# %%
#/home/jim/projects/contra/test_inputs_dump_1542319074.p
obs = pickle.load(open("test_inputs_dump_1542319074.p","rb"))
np.shape(obs)
# Out:
# (20480, 128, 112, 4)

# %%
obs_index = 19977

# %%
Image.fromarray(np.array(obs[obs_index][:,:,0]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F4C17DF7748>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,1]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F4C17DF7780>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,2]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F4C17DF7908>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,3]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F4C17DF7828>

# %%
#/home/jim/projects/contra/test_inputs_dump_1542222456.p #greyscale, half size stochastic frame skip of 6

obs = pickle.load(open("test_inputs_dump_1542222456.p","rb"))
np.shape(obs)
# Out:
# (1024, 128, 112, 4)

# %%
obs_index = 900

# %%
Image.fromarray(np.array(obs[obs_index][:,:,0]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F3160B0EF28>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,1]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F3160B0EBE0>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,2]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F3160B0E0F0>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,3]))
# Out:
# <PIL.Image.Image image mode=L size=112x128 at 0x7F3160B0EB38>

# %%
#rgb /home/jim/projects/contra/test_inputs_dump_1542220585.p

obs = pickle.load(open("test_inputs_dump_1542220585.p","rb"))
#stochastic frame skip of 4

# %%
np.shape(obs)
# Out:
# (1024, 224, 256, 12)

# %%
np.shape(obs[0])
# Out:
# (224, 256, 12)

# %%
np.shape(obs[0][:,:,0])
# Out:
# (224, 256)

# %%
obs_index = 256

# %%
Image.fromarray(np.array(obs[obs_index][:,:,0:3]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160DB4E80>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,3:6]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160DB4CF8>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,6:9]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160DB4908>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,9:12]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160DB4B00>

# %%
#more rgb, this time no stochastic frame skip
#/home/jim/projects/contra/test_inputs_dump_1542220995.p
obs = pickle.load(open("test_inputs_dump_1542220995.p","rb"))

# %%
obs_index = 10

# %%
Image.fromarray(np.array(obs[obs_index][:,:,0:3]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160C14240>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,3:6]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160C14550>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,6:9]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160C141D0>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,9:12]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160C14C50>

# %%
#more rgb, this time huge stochastic frame skip
#/home/jim/projects/contra/test_inputs_dump_1542221350.p
obs = pickle.load(open("test_inputs_dump_1542221350.p","rb"))

# %%
obs_index = 10

# %%
Image.fromarray(np.array(obs[obs_index][:,:,0:3]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160C14B00>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,3:6]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160C14588>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,6:9]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F3160C14208>

# %%
Image.fromarray(np.array(obs[obs_index][:,:,9:12]))
# Out:
# <PIL.Image.Image image mode=RGB size=256x224 at 0x7F317DD02048>

# %%
#greyscale and warped down to 84 by 84
#can't really tell wtf is going on

# %%
Image.fromarray(np.array(obs[0][:,:,0]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F3160D846D8>

# %%
Image.fromarray(np.array(obs[0][:,:,1]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F317C81BA90>

# %%
Image.fromarray(np.array(obs[0][:,:,2]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F3160D84550>

# %%
Image.fromarray(np.array(obs[0][:,:,3]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F3160D10128>

# %%
import matplotlib.pyplot as plt
for j in range(10):
    print("new group of 4")
    for i in range(0, 4):
        pil_im = Image.fromarray(np.array(obs[0][:,:,i]))
        plt.figure()
        plt.imshow(pil_im)
        plt.show()
# Out:
# new group of 4
# new group of 4
# new group of 4
# new group of 4
# new group of 4
# new group of 4
# new group of 4
# new group of 4
# new group of 4
# new group of 4

# %%
from matplotlib.pyplot import imshow
#import matplotlib.pyplot as plt
for i in range(4):
    #print(Image.fromarray(np.array(obs[0][:,:,i])))
    pil_im = Image.fromarray(np.array(obs[0][:,:,i]))
    pil_im.show()
    #imshow(np.asarray(pil_im))

# %%
import matplotlib.pyplot as plt
for j in range(len(obs)):
    if j % 100 == 0:  
        for i in range(0, 4):
            pil_im = Image.fromarray(np.array(obs[0][:,:,i]))
            plt.figure()
            plt.imshow(pil_im)
            plt.show()

# %%
# from matplotlib.pyplot import imshow
# import numpy as np
# from PIL import Image

# %matplotlib inline
# pil_im = Image.open('data/empire.jpg', 'r')
# imshow(np.asarray(pil_im))

# pil_im = Image.open('data/empire.jpg', 'r')
# pil_im.show()

# %%
def make_env(stack=True, scale_rew=True, scenario = 'scenario'): #scenario =  #'contest'
    """
    Create an environment with some standard wrappers.
    """
    #env = grc.RemoteEnv('tmp/sock')
    #env = make(game='SonicTheHedgehog-Genesis', state='SpringYardZone.Act1', bk2dir='videos', monitordir='logs',scenario=scenario)
#'BustAMove.1pplay.Level1' #BustAMove.Challengeplay0
    env = make(game='BustAMove-Snes', state='BustAMove.1pplay.Level1', bk2dir='videos', monitordir='logs',scenario=scenario)

    #env = SonicDiscretizer(env)
#     if scale_rew:
#         env = RewardScaler(env)
    env = WarpFrame(env)
    if stack:
        env = FrameStack(env, 4)
    return env

env = make_env()

# %%
env.reset()
obs_array = []

for i in range(1000):
    obs,rew,done,info = env.step(env.action_space.sample())
    #print(np.shape(obs))
    obs_array.append(obs)

# %%
#from PIL import Image
Image.fromarray(np.array(obs_array[0][:,:,0]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F693FB8B940>

# %%
Image.fromarray(np.array(obs_array[0][:,:,1]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F693FB8BA58>

# %%
Image.fromarray(np.array(obs_array[999][:,:,0]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F6903CD4630>

# %%
Image.fromarray(np.array(obs_array[999][:,:,1]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F6903CD46D8>

# %%
Image.fromarray(np.array(obs_array[999][:,:,2]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F6903CD4898>

# %%
Image.fromarray(np.array(obs_array[999][:,:,3]))
# Out:
# <PIL.Image.Image image mode=L size=84x84 at 0x7F6903CD4748>
