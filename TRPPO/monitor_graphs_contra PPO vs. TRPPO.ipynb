# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#/home/jim/projects/td3/logs/log_1541869275_1.monitor.csv

def get_results(time_id,base_dir='logs',df_mod=1):
    df_list = []
    env_name_list = []
    for i in range(100):
        file_str = '{}/log_{}_{}.monitor.csv'.format(base_dir,time_id,i)
        file_exists_check = Path(file_str)
        if file_exists_check.is_file():
            print(file_str)
            df = get_df(file_str,i)
            df_list.append(df)
            env_name = "env {}".format(i)
            env_name_list.append(env_name)
        else:
            break
    
    #get_scatter_plots(df_list)
    #get_rolling_plots(df_list)
    if len(df_list) > 0:
        describe_df_array(df_list,df_mod)
        get_rolling_comparison(df_list,env_name_list)
        if df_mod > 1:
            #rolling comparisons by df_slice too
            start_index = -1
            for i in range(0,df_mod):
                start_index += 1
                env_name_sublist = [start_index]
                base_df_list = [df_list[start_index]]
                for j in range(df_mod,len(df_list)):
                    if j % df_mod == start_index:
                        #base_df = pd.concat([base_df,df_list[j]])
                        base_df_list.append(df_list[j])
                        env_name_sublist.append(j)
                print("Doing rolling comparison for df mod {}".format(start_index))
                get_rolling_comparison(base_df_list,env_name_sublist)   
                
    else:
        print("no files found, perhaps incorrect id?")


#contra:
#first two decimal points are number of deaths with 0.01 subtracted for each death
#if you clear the level 0.5 added to deaths, have to move this out (can't lose more than 50 lives so this won't overlap)
#next 4 decimal points are number of scrolls

def get_df(file_str,i):
    mf = pd.read_csv(file_str)
    mf['t_diff'] = mf.t.diff()
    mf['deaths'] = 100 - np.floor(mf.r*100 % 100)
    mf['success'] = (mf.deaths >= 50)*1.
    mf['scrolls'] = mf.r*1000000 % 10000
    mf['deaths'][mf.deaths >= 50] = mf.deaths - 50
    mf['sc_per_d'] = mf['scrolls'] / (mf['deaths']+1)
    mf['env'] = i       
    
    return mf

def describe_df_array(df_array,df_mod=1):
    
    for i in df_array:
        print("Mean Reward last 100 Episodes per env: {}".format(np.mean(i.r.iloc[-100:])))
        
    def describe_df(mf,description=""):
        print(description)
        print(mf.describe())
        print("Max reward values:")
        print(mf.r.sort_values(ascending=False)[0:10])
        print("Max l values:")
        print(mf.l.sort_values(ascending=False)[0:10])
        print("Max score to deaths values")
        print(mf.sc_per_d.sort_values(ascending=False)[0:10])
        print("Total success {} % success {} ".format(np.sum(mf.success), np.sum(mf.success)/len(mf.success)))
    
    if df_mod <= 1:
        mf = pd.concat(df_array)
        describe_df(mf,"Combined DataFrame Description")
    else:
        start_index = -1
        for i in range(0,df_mod):
            start_index += 1
            base_df = df_array[start_index]
            for j in range(df_mod,len(df_array)):
                if j % df_mod == start_index:
                    base_df = pd.concat([base_df,df_array[j]])
                    
            describe_df(base_df,"Mod DataFrame Descriptions {}".format(start_index))
                    
                    

def get_scatter_plots(df):
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    plt.scatter(df.index,df.r,marker='.')
    plt.ylabel('reward')
    plt.xlabel('episode')
    plt.show()
    
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    plt.scatter(df.index,df.l,marker='.')
    plt.ylabel('timesteps per episode')
    plt.xlabel('episode')
    plt.show()
    
#     a4_dims = (11.7, 8.27)
#     fig, ax = plt.subplots(figsize=a4_dims)
#     plt.scatter(df.index,df.t_diff,marker='.')
#     plt.ylabel('time per episode')
#     plt.xlabel('episode')
#     plt.show()
    
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    plt.scatter(df.index,df.success,marker='.')
    plt.ylabel('success')
    plt.xlabel('episode')
    plt.show()
    
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    plt.scatter(df.index,df.sc_per_d,marker='.')
    plt.ylabel('scrolls per death')
    plt.xlabel('episode')
    plt.show()
    

def get_rolling_plots(df):
    rolling_window_size = 100
    if len(df.r) < 1000:
        rolling_window_size = 50
        
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    sns.tsplot(df.r.rolling(rolling_window_size).mean())
    plt.ylabel('reward')
    plt.xlabel('mean of last {} episodes'.format(rolling_window_size))
    plt.show()
    
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    sns.tsplot(df.l.rolling(rolling_window_size).mean())
    plt.ylabel('timesteps')
    plt.xlabel('mean of last {} episodes'.format(rolling_window_size))
    plt.show()
    
#     a4_dims = (11.7, 8.27)
#     fig, ax = plt.subplots(figsize=a4_dims)
#     sns.tsplot(df.t_diff.rolling(rolling_window_size).mean())
#     plt.ylabel('time')
#     plt.xlabel('mean of last {} episodes'.format(rolling_window_size))
#     plt.show()
    
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    sns.tsplot(df.success.rolling(rolling_window_size).mean())
    plt.ylabel('success')
    plt.xlabel('mean of last {} episodes'.format(rolling_window_size))
    plt.show()
    
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    sns.tsplot(df.sc_per_d.rolling(rolling_window_size).mean())
    plt.ylabel('scrolls per death')
    plt.xlabel('mean of last {} episodes'.format(rolling_window_size))
    plt.show()
    

        
# def get_level_comparison(lvl_array):
#     df_array = []
#     for i in range(len(lvl_array)):
#         file_str = '{}/monitor.csv'.format(lvl_array[i])
#         df_array.append(pd.read_csv(file_str))
#         df_array[i]['t_diff'] = df_array[i].t.diff()
#         df_array[i]['success'] = (df_array[i].r > 9000)*1.
#         print(lvl_array[i])
#         print(df_array[i].describe())
        
#     get_rolling_comparison(df_array,lvl_array)

    
def plot_rolling_mean(df,col_name,rolling_window_size=100):
    a4_dims = (11.7, 8.27)
    fig, ax = plt.subplots(figsize=a4_dims)
    sns.tsplot(df[col_name].rolling(rolling_window_size).mean())
    plt.ylabel(col_name)
    plt.xlabel('mean of last {} episodes'.format(rolling_window_size))
    plt.legend(loc='upper left');
    plt.show()
    
def plot_rolling_mean_array(df_list,col_name,rolling_window_size=100):
    color_dict = {0:'red', 1:'blue', 2:'green', 3:'black', 4:'grey', 5:'yellow', 6:'purple', 7:'orange'}
    color_range = len(color_dict)

    a4_dims = (14.7, 8.27)
    fig, ax1 = plt.subplots(figsize=a4_dims)
    print("Rolling Plot {}".format(col_name))
    i_range = 0;
    for i in df_list:
        sns.tsplot(i[col_name].rolling(rolling_window_size).mean(),color=color_dict[i_range%color_range])
        i_range += 1
    plt.ylabel(col_name)
    plt.xlabel('episode') 
    plt.legend(loc='upper left');
    plt.show()
    
    
def get_rolling_comparison(df_array, lvl_array):
    rolling_window_size = 100
    if len(df_array[0]) < 1000:
        rolling_window_size = 50
        
    plot_rolling_mean_array(df_array,'r',rolling_window_size)
    plot_rolling_mean_array(df_array,'l',rolling_window_size)
    plot_rolling_mean_array(df_array,'success',rolling_window_size)
    plot_rolling_mean_array(df_array,'sc_per_d',rolling_window_size)
        
    a4_dims = (14.7, 8.27)
    fig, ax1 = plt.subplots(figsize=a4_dims)
    print("Reward Scatter Plot")
    i_range = 0;
    for i in df_array:
        ax1.scatter(i.index,i.r,marker='.',label=i_range)
        i_range += 1
    plt.ylabel('reward')
    plt.xlabel('episode') 
    plt.legend(loc='upper left');
    plt.show()
    
    a4_dims = (14.7, 8.27)
    fig, ax1 = plt.subplots(figsize=a4_dims)
    print("Timesteps Scatter Plot")
    i_range = 0;
    for i in df_array:
        ax1.scatter(i.index,i.l,marker='.',label=i_range)
        i_range += 1
    plt.ylabel('Timesteps')
    plt.xlabel('episode') 
    plt.legend(loc='upper left');
    plt.show()
    
    a4_dims = (14.7, 8.27)
    fig, ax1 = plt.subplots(figsize=a4_dims)
    print("Success Scatter Plot")
    i_range = 0;
    for i in df_array:
        ax1.scatter(i.index,i.success,marker='.',label=i_range)
        i_range += 1
    plt.ylabel('Success')
    plt.xlabel('episode') 
    plt.legend(loc='upper left');
    plt.show()
    
#     temp_index = 0
#     for i in df_array:
#         print(lvl_array[temp_index], " reward")
#         temp_index += 1
#         plot_rolling_mean(i,'r',rolling_window_size)
        
#     temp_index = 0
#     for i in df_array:
#         print(lvl_array[temp_index], " success")
#         temp_index += 1
#         plot_rolling_mean(i,'success',rolling_window_size)
        
# #     temp_index = 0
# #     for i in df_array:
# #         print(lvl_array[temp_index], " timesteps")
# #         temp_index += 1
# #         plot_rolling_mean(i,'l',rolling_window_size)

#     temp_index = 0
#     for i in df_array:
#         print(lvl_array[temp_index], "Scrolls Per Death")
#         temp_index += 1
#         plot_rolling_mean(i,'sc_per_d',rolling_window_size)

#     temp_index = 0
#     for i in df_array:
#         a4_dims = (11.7, 8.27)
#         fig, ax = plt.subplots(figsize=a4_dims)
#         print(lvl_array[temp_index], " reward")
#         plt.scatter(i.index,i.r,marker='.')
#         plt.ylabel('reward')
#         plt.xlabel('episode')
#         plt.show()    
#         temp_index += 1
        
#     temp_index = 0
#     for i in df_array:
#         a4_dims = (11.7, 8.27)
#         fig, ax = plt.subplots(figsize=a4_dims)
#         print(lvl_array[temp_index], " success")
#         plt.scatter(i.index,i.success,marker='.')
#         plt.ylabel('success')
#         plt.xlabel('episode')
#         plt.show()    
#         temp_index += 1

# %%
#TRPO 1549137337
get_results(time_id=1549137337,base_dir='logs',df_mod=1)
# Out:
# logs/log_1549137337_0.monitor.csv
# logs/log_1549137337_1.monitor.csv
# logs/log_1549137337_2.monitor.csv
# /home/paperspace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# logs/log_1549137337_3.monitor.csv
# logs/log_1549137337_4.monitor.csv
# logs/log_1549137337_5.monitor.csv
# logs/log_1549137337_6.monitor.csv
# logs/log_1549137337_7.monitor.csv
# logs/log_1549137337_8.monitor.csv
# logs/log_1549137337_9.monitor.csv
# logs/log_1549137337_10.monitor.csv
# logs/log_1549137337_11.monitor.csv
# logs/log_1549137337_12.monitor.csv
# logs/log_1549137337_13.monitor.csv
# logs/log_1549137337_14.monitor.csv
# logs/log_1549137337_15.monitor.csv
# logs/log_1549137337_16.monitor.csv
# logs/log_1549137337_17.monitor.csv
# logs/log_1549137337_18.monitor.csv
# logs/log_1549137337_19.monitor.csv
# logs/log_1549137337_20.monitor.csv
# logs/log_1549137337_21.monitor.csv
# logs/log_1549137337_22.monitor.csv
# logs/log_1549137337_23.monitor.csv
# logs/log_1549137337_24.monitor.csv
# logs/log_1549137337_25.monitor.csv
# logs/log_1549137337_26.monitor.csv
# logs/log_1549137337_27.monitor.csv
# logs/log_1549137337_28.monitor.csv
# logs/log_1549137337_29.monitor.csv
# logs/log_1549137337_30.monitor.csv
# logs/log_1549137337_31.monitor.csv
# logs/log_1549137337_32.monitor.csv
# logs/log_1549137337_33.monitor.csv
# logs/log_1549137337_34.monitor.csv
# logs/log_1549137337_35.monitor.csv
# logs/log_1549137337_36.monitor.csv
# logs/log_1549137337_37.monitor.csv
# logs/log_1549137337_38.monitor.csv
# logs/log_1549137337_39.monitor.csv
# logs/log_1549137337_40.monitor.csv
# logs/log_1549137337_41.monitor.csv
# Mean Reward last 100 Episodes per env: 2484.7722318199994
# Mean Reward last 100 Episodes per env: 2457.3622076300003
# Mean Reward last 100 Episodes per env: 2483.8822249500013
# Mean Reward last 100 Episodes per env: 2487.692239300001
# Mean Reward last 100 Episodes per env: 2501.58223899
# Mean Reward last 100 Episodes per env: 2488.232131780001
# Mean Reward last 100 Episodes per env: 2500.9822373100005
# Mean Reward last 100 Episodes per env: 2506.9822547300005
# Mean Reward last 100 Episodes per env: 2522.162259070001
# Mean Reward last 100 Episodes per env: 2482.32222003
# Mean Reward last 100 Episodes per env: 2476.0422264700014
# Mean Reward last 100 Episodes per env: 2479.29222108
# Mean Reward last 100 Episodes per env: 2486.0622306300015
# Mean Reward last 100 Episodes per env: 2452.61220924
# Mean Reward last 100 Episodes per env: 2509.5822525500007
# Mean Reward last 100 Episodes per env: 2460.4422101100004
# Mean Reward last 100 Episodes per env: 2452.412202460001
# Mean Reward last 100 Episodes per env: 2506.2522473000004
# Mean Reward last 100 Episodes per env: 2461.542203290002
# Mean Reward last 100 Episodes per env: 2455.0722012800015
# Mean Reward last 100 Episodes per env: 2460.74221649
# Mean Reward last 100 Episodes per env: 2478.0422233900017
# Mean Reward last 100 Episodes per env: 2452.4021937900015
# Mean Reward last 100 Episodes per env: 2487.682231970002
# Mean Reward last 100 Episodes per env: 2477.88222927
# Mean Reward last 100 Episodes per env: 2460.6622056700007
# Mean Reward last 100 Episodes per env: 2486.24224061
# Mean Reward last 100 Episodes per env: 2527.6422620300004
# Mean Reward last 100 Episodes per env: 2500.192238160001
# Mean Reward last 100 Episodes per env: 2502.4922389200024
# Mean Reward last 100 Episodes per env: 2484.932233720001
# Mean Reward last 100 Episodes per env: 2531.7522632200003
# Mean Reward last 100 Episodes per env: 2445.7922056400007
# Mean Reward last 100 Episodes per env: 2456.7422119100015
# Mean Reward last 100 Episodes per env: 2485.892134200001
# Mean Reward last 100 Episodes per env: 2476.942220790001
# Mean Reward last 100 Episodes per env: 2447.282196710001
# Mean Reward last 100 Episodes per env: 2479.82223453
# Mean Reward last 100 Episodes per env: 2507.5722486200016
# Mean Reward last 100 Episodes per env: 2493.832240780001
# Mean Reward last 100 Episodes per env: 2467.2722104799996
# Mean Reward last 100 Episodes per env: 2496.492236860001
# Combined DataFrame Description
#                  r             l             t        t_diff       deaths  \
# count  7935.000000   7935.000000   7935.000000   7893.000000  7935.000000
# mean   2041.386432   7454.200756  48603.538407    389.036723     7.000252
# std     727.498398   2555.144466  17073.052736   1855.630285     0.015875
# min     157.930228   1109.000000    144.358142     26.529378     7.000000
# 25%    1902.931761   6269.000000  39986.003470    188.563786     7.000000
# 50%    2118.931977   7653.000000  49998.307417    232.866934     7.000000
# 75%    2452.932219   8686.500000  61204.511496    258.766283     7.000000
# max    3481.932984  31541.000000  73465.164737  32829.422723     8.000000
#
#        success      scrolls     sc_per_d          env
# count   7935.0  7935.000000  7935.000000  7935.000000
# mean       0.0  1866.033018   233.243667    20.525772
# std        0.0   609.364800    76.154186    12.096862
# min        0.0   228.000000    28.500000     0.000000
# 25%        0.0  1761.000000   220.125000    10.000000
# 50%        0.0  1977.000000   247.125000    21.000000
# 75%        0.0  2219.000000   277.375000    31.000000
# max        0.0  2997.000000   374.625000    41.000000
# Max reward values:
# 176    3481.932984
# 173    3477.932986
# 195    3473.922988
# 183    3461.922988
# 192    3454.932983
# 186    3449.932984
# 170    3443.932990
# 182    3442.932993
# 182    3433.932988
# 179    3432.932987
# Name: r, dtype: float64
# Max l values:
# 12    31541
# 13    31459
# 14    30076
# 12    29757
# 17    28552
# 12    28009
# 12    27807
# 13    27776
# 12    26722
# 13    25950
# Name: l, dtype: int64
# Max score to deaths values
# 165    374.625
# 171    374.250
# 182    374.125
# 163    374.125
# 161    374.125
# 182    374.000
# 191    374.000
# 177    374.000
# 169    374.000
# 178    373.875
# Name: sc_per_d, dtype: float64
# Total success 0.0 % success 0.0
# Rolling Plot r
# /home/paperspace/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# Rolling Plot l
# No handles with labels found to put in legend.
# Rolling Plot success
# No handles with labels found to put in legend.
# Rolling Plot sc_per_d
# No handles with labels found to put in legend.
# Reward Scatter Plot
# Timesteps Scatter Plot
# Success Scatter Plot

# %%
#levl 3 run 2
#1543250749
get_results(time_id=1543250749,base_dir='logs',df_mod=1)
# Out:
# logs/log_1543250749_0.monitor.csv
# /home/paperspace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# logs/log_1543250749_1.monitor.csv
# logs/log_1543250749_2.monitor.csv
# logs/log_1543250749_3.monitor.csv
# logs/log_1543250749_4.monitor.csv
# logs/log_1543250749_5.monitor.csv
# logs/log_1543250749_6.monitor.csv
# logs/log_1543250749_7.monitor.csv
# logs/log_1543250749_8.monitor.csv
# logs/log_1543250749_9.monitor.csv
# logs/log_1543250749_10.monitor.csv
# logs/log_1543250749_11.monitor.csv
# logs/log_1543250749_12.monitor.csv
# logs/log_1543250749_13.monitor.csv
# logs/log_1543250749_14.monitor.csv
# logs/log_1543250749_15.monitor.csv
# logs/log_1543250749_16.monitor.csv
# logs/log_1543250749_17.monitor.csv
# logs/log_1543250749_18.monitor.csv
# logs/log_1543250749_19.monitor.csv
# logs/log_1543250749_20.monitor.csv
# logs/log_1543250749_21.monitor.csv
# logs/log_1543250749_22.monitor.csv
# logs/log_1543250749_23.monitor.csv
# logs/log_1543250749_24.monitor.csv
# logs/log_1543250749_25.monitor.csv
# logs/log_1543250749_26.monitor.csv
# logs/log_1543250749_27.monitor.csv
# logs/log_1543250749_28.monitor.csv
# logs/log_1543250749_29.monitor.csv
# logs/log_1543250749_30.monitor.csv
# logs/log_1543250749_31.monitor.csv
# logs/log_1543250749_32.monitor.csv
# logs/log_1543250749_33.monitor.csv
# logs/log_1543250749_34.monitor.csv
# logs/log_1543250749_35.monitor.csv
# logs/log_1543250749_36.monitor.csv
# logs/log_1543250749_37.monitor.csv
# logs/log_1543250749_38.monitor.csv
# logs/log_1543250749_39.monitor.csv
# logs/log_1543250749_40.monitor.csv
# logs/log_1543250749_41.monitor.csv
# Mean Reward last 100 Episodes per env: 5718.873397560001
# Mean Reward last 100 Episodes per env: 6055.132720120001
# Mean Reward last 100 Episodes per env: 5729.113388019998
# Mean Reward last 100 Episodes per env: 5710.042648829999
# Mean Reward last 100 Episodes per env: 5860.212898779998
# Mean Reward last 100 Episodes per env: 5454.053370420001
# Mean Reward last 100 Episodes per env: 5636.623280229999
# Mean Reward last 100 Episodes per env: 5720.673241619999
# Mean Reward last 100 Episodes per env: 5724.973239019999
# Mean Reward last 100 Episodes per env: 5703.143265129999
# Mean Reward last 100 Episodes per env: 5784.923199449999
# Mean Reward last 100 Episodes per env: 5907.363618309999
# Mean Reward last 100 Episodes per env: 5899.193026479999
# Mean Reward last 100 Episodes per env: 5841.413487919998
# Mean Reward last 100 Episodes per env: 5586.172772920001
# Mean Reward last 100 Episodes per env: 5933.013318240001
# Mean Reward last 100 Episodes per env: 5698.683199310001
# Mean Reward last 100 Episodes per env: 5564.152991739997
# Mean Reward last 100 Episodes per env: 5432.1633663699995
# Mean Reward last 100 Episodes per env: 5757.642290069999
# Mean Reward last 100 Episodes per env: 5319.083486289997
# Mean Reward last 100 Episodes per env: 5951.742999649998
# Mean Reward last 100 Episodes per env: 5761.882973469998
# Mean Reward last 100 Episodes per env: 5573.003039929999
# Mean Reward last 100 Episodes per env: 5951.7336676800005
# Mean Reward last 100 Episodes per env: 5676.483077809997
# Mean Reward last 100 Episodes per env: 5679.023345450001
# Mean Reward last 100 Episodes per env: 5832.233010239999
# Mean Reward last 100 Episodes per env: 5451.083166950001
# Mean Reward last 100 Episodes per env: 5817.622944630001
# Mean Reward last 100 Episodes per env: 5576.723550029998
# Mean Reward last 100 Episodes per env: 5743.493666680002
# Mean Reward last 100 Episodes per env: 5522.723616350001
# Mean Reward last 100 Episodes per env: 5535.073832059999
# Mean Reward last 100 Episodes per env: 5614.712922019998
# Mean Reward last 100 Episodes per env: 5628.5833497700005
# Mean Reward last 100 Episodes per env: 5740.83312342
# Mean Reward last 100 Episodes per env: 5786.313222780001
# Mean Reward last 100 Episodes per env: 5756.21314718
# Mean Reward last 100 Episodes per env: 5874.56335295
# Mean Reward last 100 Episodes per env: 5689.533509879997
# Mean Reward last 100 Episodes per env: 5507.09330356
# Combined DataFrame Description
#                   r             l              t        t_diff        deaths  \
# count  69067.000000  69067.000000   69067.000000  69025.000000  69067.000000
# mean    4137.420764   9007.688636  248698.298605    311.662904      7.029609
# std     1885.321810   3022.207188  144216.736391    748.881323      0.169507
# min      156.930227   1116.000000      63.275998     25.965220      7.000000
# 25%     2433.932218   6731.000000  116458.956447    213.884244      7.000000
# 50%     4010.933349  10074.000000  231839.293715    312.153135      7.000000
# 75%     5925.934637  11488.000000  377653.806445    363.861449      7.000000
# max     8714.924633  31976.000000  512501.632565  43999.363471      8.000000
#
#        success       scrolls      sc_per_d           env
# count  69067.0  69067.000000  69067.000000  69067.000000
# mean       0.0   3273.368020    407.312894     20.506001
# std        0.0   1201.443697    148.597845     12.117889
# min        0.0    227.000000     28.375000      0.000000
# 25%        0.0   2218.000000    277.250000     10.000000
# 50%        0.0   3348.000000    418.500000     20.000000
# 75%        0.0   4611.000000    576.250000     31.000000
# max        0.0   4672.000000    584.000000     41.000000
# Max reward values:
# 1275    8714.924633
# 1308    8710.924603
# 1322    8696.924609
# 1493    8695.934610
# 1161    8681.924620
# 1313    8678.924619
# 1359    8667.924618
# 1452    8660.924609
# 1469    8659.924612
# 1418    8642.924615
# Name: r, dtype: float64
# Max l values:
# 1485    31976
# 22      31925
# 16      31861
# 14      31198
# 13      31101
# 1384    31006
# 15      30952
# 15      30897
# 10      30897
# 408     30848
# Name: l, dtype: int64
# Max score to deaths values
# 909     584.000
# 1239    583.875
# 959     583.750
# 764     583.625
# 828     583.625
# 1069    583.625
# 734     583.625
# 824     583.500
# 730     583.500
# 803     583.375
# Name: sc_per_d, dtype: float64
# Total success 0.0 % success 0.0
# Rolling Plot r
# /home/paperspace/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# Rolling Plot l
# No handles with labels found to put in legend.
# Rolling Plot success
# No handles with labels found to put in legend.
# Rolling Plot sc_per_d
# No handles with labels found to put in legend.
# Reward Scatter Plot
# Timesteps Scatter Plot
# Success Scatter Plot

# %%
#truncated results for long run
def get_truncated_results(time_id,base_dir='logs',df_mod=1):
    df_list = []
    env_name_list = []
    for i in range(100):
        file_str = '{}/log_{}_{}.monitor.csv'.format(base_dir,time_id,i)
        file_exists_check = Path(file_str)
        if file_exists_check.is_file():
            print(file_str)
            df = get_df(file_str,i)
            df = df.head(200)
            df_list.append(df)
            env_name = "env {}".format(i)
            env_name_list.append(env_name)
        else:
            break
    
    #get_scatter_plots(df_list)
    #get_rolling_plots(df_list)
    if len(df_list) > 0:
        describe_df_array(df_list,df_mod)
        get_rolling_comparison(df_list,env_name_list)
        if df_mod > 1:
            #rolling comparisons by df_slice too
            start_index = -1
            for i in range(0,df_mod):
                start_index += 1
                env_name_sublist = [start_index]
                base_df_list = [df_list[start_index]]
                for j in range(df_mod,len(df_list)):
                    if j % df_mod == start_index:
                        #base_df = pd.concat([base_df,df_list[j]])
                        base_df_list.append(df_list[j])
                        env_name_sublist.append(j)
                print("Doing rolling comparison for df mod {}".format(start_index))
                get_rolling_comparison(base_df_list,env_name_sublist)   
                
    else:
        print("no files found, perhaps incorrect id?")

# %%
#levl 3 run 2
#First 250 episodes
#1543250749
get_truncated_results(time_id=1543250749,base_dir='logs',df_mod=1)
# Out:
# logs/log_1543250749_0.monitor.csv
# /home/paperspace/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# logs/log_1543250749_1.monitor.csv
# logs/log_1543250749_2.monitor.csv
# logs/log_1543250749_3.monitor.csv
# logs/log_1543250749_4.monitor.csv
# logs/log_1543250749_5.monitor.csv
# logs/log_1543250749_6.monitor.csv
# logs/log_1543250749_7.monitor.csv
# logs/log_1543250749_8.monitor.csv
# logs/log_1543250749_9.monitor.csv
# logs/log_1543250749_10.monitor.csv
# logs/log_1543250749_11.monitor.csv
# logs/log_1543250749_12.monitor.csv
# logs/log_1543250749_13.monitor.csv
# logs/log_1543250749_14.monitor.csv
# logs/log_1543250749_15.monitor.csv
# logs/log_1543250749_16.monitor.csv
# logs/log_1543250749_17.monitor.csv
# logs/log_1543250749_18.monitor.csv
# logs/log_1543250749_19.monitor.csv
# logs/log_1543250749_20.monitor.csv
# logs/log_1543250749_21.monitor.csv
# logs/log_1543250749_22.monitor.csv
# logs/log_1543250749_23.monitor.csv
# logs/log_1543250749_24.monitor.csv
# logs/log_1543250749_25.monitor.csv
# logs/log_1543250749_26.monitor.csv
# logs/log_1543250749_27.monitor.csv
# logs/log_1543250749_28.monitor.csv
# logs/log_1543250749_29.monitor.csv
# logs/log_1543250749_30.monitor.csv
# logs/log_1543250749_31.monitor.csv
# logs/log_1543250749_32.monitor.csv
# logs/log_1543250749_33.monitor.csv
# logs/log_1543250749_34.monitor.csv
# logs/log_1543250749_35.monitor.csv
# logs/log_1543250749_36.monitor.csv
# logs/log_1543250749_37.monitor.csv
# logs/log_1543250749_38.monitor.csv
# logs/log_1543250749_39.monitor.csv
# logs/log_1543250749_40.monitor.csv
# logs/log_1543250749_41.monitor.csv
# Mean Reward last 100 Episodes per env: 2050.9319062200007
# Mean Reward last 100 Episodes per env: 2043.3718957399992
# Mean Reward last 100 Episodes per env: 2064.84191649
# Mean Reward last 100 Episodes per env: 2029.8218765100014
# Mean Reward last 100 Episodes per env: 2014.0318719600007
# Mean Reward last 100 Episodes per env: 2001.451859
# Mean Reward last 100 Episodes per env: 2077.721923890001
# Mean Reward last 100 Episodes per env: 2045.0718989200004
# Mean Reward last 100 Episodes per env: 2004.5218574699995
# Mean Reward last 100 Episodes per env: 2051.0419037300007
# Mean Reward last 100 Episodes per env: 2094.321935890001
# Mean Reward last 100 Episodes per env: 2050.19190148
# Mean Reward last 100 Episodes per env: 1993.0618507699996
# Mean Reward last 100 Episodes per env: 2048.86189649
# Mean Reward last 100 Episodes per env: 2031.731887220001
# Mean Reward last 100 Episodes per env: 2023.3518752399998
# Mean Reward last 100 Episodes per env: 2020.4418717699998
# Mean Reward last 100 Episodes per env: 2020.851871500001
# Mean Reward last 100 Episodes per env: 2027.5418726900004
# Mean Reward last 100 Episodes per env: 2126.241971050001
# Mean Reward last 100 Episodes per env: 2008.2518634400008
# Mean Reward last 100 Episodes per env: 1993.7518451600001
# Mean Reward last 100 Episodes per env: 2043.3118991199997
# Mean Reward last 100 Episodes per env: 2039.0318915800005
# Mean Reward last 100 Episodes per env: 2026.7518811600007
# Mean Reward last 100 Episodes per env: 2026.30188035
# Mean Reward last 100 Episodes per env: 2069.411915240001
# Mean Reward last 100 Episodes per env: 2015.4418635100008
# Mean Reward last 100 Episodes per env: 2044.801885750001
# Mean Reward last 100 Episodes per env: 2062.2919131399995
# Mean Reward last 100 Episodes per env: 2070.691912059999
# Mean Reward last 100 Episodes per env: 2047.1418984700008
# Mean Reward last 100 Episodes per env: 2108.2019543900005
# Mean Reward last 100 Episodes per env: 2015.0418691699992
# Mean Reward last 100 Episodes per env: 2042.361889950001
# Mean Reward last 100 Episodes per env: 1985.7818409300003
# Mean Reward last 100 Episodes per env: 2051.2218945700006
# Mean Reward last 100 Episodes per env: 2039.6818928500006
# Mean Reward last 100 Episodes per env: 2056.3519071
# Mean Reward last 100 Episodes per env: 2053.4619025900006
# Mean Reward last 100 Episodes per env: 2045.0518980200004
# Mean Reward last 100 Episodes per env: 2058.9619100300006
# Combined DataFrame Description
#                  r             l             t        t_diff  deaths  success  \
# count  8400.000000   8400.000000   8400.000000   8358.000000  8400.0   8400.0
# mean   1767.592365   5061.690000  54778.970876    367.196695     7.0      0.0
# std     582.881375   2473.997043  16117.073973   2136.871530     0.0      0.0
# min     156.930227   1134.000000     63.275998     27.092608     7.0      0.0
# 25%    1745.931604   3930.000000  50166.329041    122.568271     7.0      0.0
# 50%    1862.931721   4718.000000  57329.211758    143.431318     7.0      0.0
# 75%    2075.931934   5618.250000  64835.328982    179.268975     7.0      0.0
# max    2771.932338  31925.000000  75735.394728  43999.363471     7.0      0.0
#
#            scrolls     sc_per_d         env
# count  8400.000000  8400.000000  8400.00000
# mean   1650.294762   206.286845    20.50000
# std     514.138891    64.267361    12.12164
# min     227.000000    28.375000     0.00000
# 25%    1604.000000   200.500000    10.00000
# 50%    1721.000000   215.125000    20.50000
# 75%    1934.000000   241.750000    31.00000
# max    2338.000000   292.250000    41.00000
# Max reward values:
# 155    2771.932338
# 191    2768.932335
# 168    2764.932331
# 199    2761.932328
# 165    2751.932318
# 197    2745.932312
# 191    2744.932311
# 178    2743.932310
# 197    2730.932297
# 181    2694.932261
# Name: r, dtype: float64
# Max l values:
# 22    31925
# 16    31861
# 14    31198
# 13    31101
# 15    30952
# 15    30897
# 10    30897
# 16    30509
# 14    30345
# 11    30091
# Name: l, dtype: int64
# Max score to deaths values
# 155    292.250
# 191    291.875
# 168    291.375
# 199    291.000
# 165    289.750
# 197    289.000
# 191    288.875
# 178    288.750
# 197    287.125
# 181    282.625
# Name: sc_per_d, dtype: float64
# Total success 0.0 % success 0.0
# Rolling Plot r
# /home/paperspace/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# Rolling Plot l
# No handles with labels found to put in legend.
# Rolling Plot success
# No handles with labels found to put in legend.
# Rolling Plot sc_per_d
# No handles with labels found to put in legend.
# Reward Scatter Plot
# Timesteps Scatter Plot
# Success Scatter Plot
